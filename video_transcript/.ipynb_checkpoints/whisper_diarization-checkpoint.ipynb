# %%
# !git clone https://github.com/MahmoudAshraf97/whisper-diarization.git
# Out:
# Cloning into 'whisper-diarization'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 206 (delta 98), reused 99 (delta 87), pack-reused 76
# Receiving objects: 100% (206/206), 71.52 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
# !pip install cython
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,082 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,347 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
cd /content/whisper-diarization
# Out:
# /content/whisper-diarization

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/m-bain/whisperX.git (to revision 051047bb25b740fed2ea93ca737499c37e8dc9d4) to /tmp/pip-req-build-axh_stkm
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperX.git /tmp/pip-req-build-axh_stkm
#   Running command git rev-parse -q --verify 'sha^051047bb25b740fed2ea93ca737499c37e8dc9d4'
#   Running command git fetch -q https://github.com/m-bain/whisperX.git 051047bb25b740fed2ea93ca737499c37e8dc9d4
#   Running command git checkout -q 051047bb25b740fed2ea93ca737499c37e8dc9d4
#   Resolved https://github.com/m-bain/whisperX.git to commit 051047bb25b740fed2ea93ca737499c37e8dc9d4
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/demucs to /tmp/pip-install-uhm0rpei/demucs_41ba329b2fae448ea7a5d56c13ba5167
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs /tmp/pip-install-uhm0rpei/demucs_41ba329b2fae448ea7a5d56c13ba5167
# ...

# %%
# !python diarize_parallel.py -a /content/drive/MyDrive/BU_fall23/sparkml/project/videos/AXON_Body_2_Video_2020-05-31_2055-002.mp4 --whisper-model large-v2
# Out:
# 2023-10-17 18:48:29.027035: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /content/whisper-diarization/temp_outputs/htdemucs
# Separating track /content/drive/MyDrive/BU_fall23/sparkml/project/videos/AXON_Body_2_Video_2020-05-31_2055-002.mp4
# Killed
# WARNING:root:Source splitting failed, using original audio file. Use --no-stem argument to disable it.
# ...
#
# ...
#
# ...
#
# ...
# 2023-10-17 18:50:12.109741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [NeMo I 2023-10-17 18:51:17 msdd_models:1092] Loading pretrained diar_msdd_telephonic model from NGC
# [NeMo I 2023-10-17 18:51:17 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.20.0/diar_msdd_telephonic/3c3697a0a46f945574fa407149975a13/diar_msdd_telephonic.nemo.
# ...

# %%
import moviepy.editor as mp
clip = mp.VideoFileClip("/content/drive/MyDrive/BU_fall23/sparkml/project/videos/AXON_Body_2_Video_2020-05-31_2055-002.mp4").subclip(0,20)
clip.audio.write_audiofile("AXON_Body_2_Video_2020-05-31_2055-002_audio.mp3")
